# %%
import toml
import os,sys
MEDULLA_PATH = '/exp/sbnd/app/users/brindenc/develop/medulla_area/medulla'
sys.path.append(MEDULLA_PATH)
sys.path.append(os.path.join(MEDULLA_PATH,'spineplot'))
sys.path.append(os.getcwd())
from analysis import Analysis

from matplotlib import pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
analysis_mc_cfg = """
[analysis]
ordinate_sample = 'mc_nu'
category_branch = 'true_category'
category_assignment = [[0], [1], [2,3], [4], [5], [6], [7]]
category_labels = ['$\\nu_\\mu$ CC (cont.)', '$\\nu_\\mu$ CC (exit)', '$\\nu_\\mu$ CC (OOPS)', 'Non-AV', '$\\nu_e$ CC', 'NC', 'Cosmic']
category_colors = ['gold','goldenrod','purple','sienna','blue','green','red']
category_types = ['histogram', 'histogram', 'histogram', 'histogram', 'histogram', 'histogram', 'histogram']
"""

analysis_mc_nobkg_cfg = """
[analysis]
ordinate_sample = 'mc_nu'
category_branch = 'true_category'
category_assignment = [[0], [1]]
category_labels = ['$\\nu_\\mu$ CC (cont.)', '$\\nu_\\mu$ CC (exit)']
category_colors = ['gold','goldenrod']
category_types = ['histogram', 'histogram']
"""
# category_assignment = [[0], [1], [2,3], [4], [5], [6], [7]]
# category_labels = ['$\\nu_\\mu$ CC (cont.)', '$\\nu_\\mu$ CC (exit)', '$\\nu_\\mu$ CC (OOPS)', 'Non-AV', '$\\nu_e$ CC', 'NC', 'Cosmic']
# category_colors = ['gold','goldenrod','purple','sienna','blue','green','red']
# category_types = ['histogram', 'histogram', 'histogram', 'histogram', 'histogram', 'histogram', 'histogram']
analysis_eff_cfg = """
[analysis]
ordinate_sample = 'mc_nu'
category_branch = 'true_category'
category_assignment = [[0,1], [2,3], [4], [5], [6], [7]]
category_labels = ['$\\nu_\\mu$ CC', '$\\nu_\\mu$ CC (OOPS)', 'Non-AV', '$\\nu_e$ CC', 'NC', 'Cosmic']
category_colors = ['gold','purple','sienna','blue','green','red']
category_types = ['histogram', 'histogram', 'histogram', 'histogram', 'histogram', 'histogram']
"""

analysis_data_cfg = """
[analysis]
ordinate_sample = 'data'
category_branch = 'true_category'
category_assignment = [[0], [1], [2,3], [4], [5], [6], [7], [-1]]
category_labels = ['$\\nu_\\mu$ CC (cont.)', '$\\nu_\\mu$ CC (exit)', '$\\nu_\\mu$ CC (OOPS)', 'Non-AV', '$\\nu_e$ CC', 'NC', 'Cosmic', 'Data']
category_colors = ['gold','goldenrod','purple','sienna','blue','green','red', 'black']
category_types = ['histogram', 'histogram', 'histogram', 'histogram', 'histogram', 'histogram', 'histogram', 'scatter']
"""

spectra_plots = """
[[figure]]
name = 'reco_leading_muon_momentum_gev'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_leading_muon_momentum_gev'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false, 'save_csv_name' = '/exp/sbnd/data/users/brindenc/medulla/test/tmp/reco_leading_muon_momentum_gev.csv'}

[[figure]]
name = 'reco_leading_muon_costheta'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_leading_muon_costheta'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false, 'save_csv_name' = '/exp/sbnd/data/users/brindenc/medulla/test/tmp/reco_leading_muon_costheta.csv'}

"""
# [[figure]]
# name = 'reco_leading_muon_start_dedx'
# type = 'SimpleFigure'
# style = 'selected_sbnd'
# [[figure.artists]]
# type = 'SpineSpectra1D'
# variable = 'reco_leading_muon_start_dedx'
# draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}

# [[figure]]
# name = 'reco_leading_muon_length'
# type = 'SimpleFigure'
# style = 'selected_sbnd'
# [[figure.artists]]
# type = 'SpineSpectra1D'
# variable = 'reco_leading_muon_length'
# draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}

flash_plots = """
[[figure]]
name = 'reco_flash_hypothesis'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_flash_hypothesis'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}

[[figure]]
name = 'reco_flash_total_pe'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_flash_total_pe'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}

[[figure]]
name = 'reco_flash_score'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_flash_score'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false, 'logx' = true, 'bbox_to_anchor' = [1.0, 1.0], 'loc' = 'upper left'}

[[figure]]
name = 'reco_flash_time'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_flash_time'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}
"""

endpoint_plots = """
[[figure]]
name = 'reco_leading_muon_end_x'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_leading_muon_end_x'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false, 'bbox_to_anchor' = [1.0, 1.0], 'loc' = 'upper left'}

[[figure]]
name = 'reco_leading_muon_end_y'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_leading_muon_end_y'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false , 'bbox_to_anchor' = [1.0, 1.0], 'loc' = 'upper left'}

[[figure]]
name = 'reco_leading_muon_end_z'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_leading_muon_end_z'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false , 'bbox_to_anchor' = [1.0, 1.0], 'loc' = 'upper left'}

[[figure]]
name = 'reco_leading_muon_start_x'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_leading_muon_start_x'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false , 'bbox_to_anchor' = [1.0, 1.0], 'loc' = 'upper left'}

[[figure]]
name = 'reco_leading_muon_start_y'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_leading_muon_start_y'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false , 'bbox_to_anchor' = [1.0, 1.0], 'loc' = 'upper left'}

[[figure]]
name = 'reco_leading_muon_start_z'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_leading_muon_start_z'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false , 'bbox_to_anchor' = [1.0, 1.0], 'loc' = 'upper left'}

[[figure]]
name = 'reco_vertex_x'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_vertex_x'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false , 'bbox_to_anchor' = [1.0, 1.0], 'loc' = 'upper left'}

[[figure]]
name = 'reco_vertex_y'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_vertex_y'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false , 'bbox_to_anchor' = [1.0, 1.0], 'loc' = 'upper left'}

[[figure]]
name = 'reco_vertex_z'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_vertex_z'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false , 'bbox_to_anchor' = [1.0, 1.0], 'loc' = 'upper left'}
"""

nn_score_plots = """
[[figure]]
name = 'reco_leading_muon_muon_softmax'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_leading_muon_muon_softmax'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}

[[figure]]
name = 'reco_leading_muon_pion_softmax'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_leading_muon_pion_softmax'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}

[[figure]]
name = 'reco_leading_muon_proton_softmax'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_leading_muon_proton_softmax'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}

[[figure]]
name = 'reco_leading_muon_primary_softmax'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_leading_muon_primary_softmax'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}

[[figure]]
name = 'reco_leading_pion_muon_softmax'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_leading_pion_muon_softmax'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}

[[figure]]
name = 'reco_leading_pion_pion_softmax'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_leading_pion_pion_softmax'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false, 'bbox_to_anchor' = [1.0, 1.0], 'loc' = 'upper left'}

[[figure]]
name = 'reco_leading_pion_proton_softmax'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_leading_pion_proton_softmax'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}

[[figure]]
name = 'reco_leading_pion_primary_softmax'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_leading_pion_primary_softmax'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}
"""

eff_plots = """
[[figure]]
name = 'eff_true_leading_muon_momentum_gev'
type = 'SimpleFigure'
style = 'basic_sbnd'
[[figure.artists]]
type = 'SpineEfficiency'
variable = 'true_leading_muon_momentum_gev'
groups = ['$\\nu_\\mu$ CC']
cuts = {'reco_valid_flashmatch' = 'Flash Match', 'reco_fiducial_bool' = 'Fiducial', 'reco_has_muon_bool' = 'Has Muon', 'reco_leading_muon_start_dedx_bool' = 'Start dE/dx', 'reco_flash_score_bool' = 'Flash Score'}
draw_kwargs = {'show_option' = 'differential', 'percentage' = true, 'show_seqeff' = true, 'show_unseqeff' = true}

[[figure]]
name = 'eff_true_leading_muon_costheta'
type = 'SimpleFigure'
style = 'basic_sbnd'
[[figure.artists]]
type = 'SpineEfficiency'
variable = 'true_leading_muon_costheta'
groups = ['$\\nu_\\mu$ CC']
cuts = {'reco_valid_flashmatch' = 'Flash Match', 'reco_fiducial_bool' = 'Fiducial', 'reco_has_muon_bool' = 'Has Muon', 'reco_leading_muon_start_dedx_bool' = 'Start dE/dx', 'reco_flash_score_bool' = 'Flash Score'}
draw_kwargs = {'show_option' = 'differential', 'percentage' = true, 'show_seqeff' = true, 'show_unseqeff' = true}

[[figure]]
name = 'eff_reco_leading_muon_momentum_gev'
type = 'SimpleFigure'
style = 'basic_sbnd'
[[figure.artists]]
type = 'SpineEfficiency'
variable = 'reco_leading_muon_momentum_gev'
groups = ['$\\nu_\\mu$ CC']
cuts = {'reco_valid_flashmatch' = 'Flash Match', 'reco_fiducial_bool' = 'Fiducial', 'reco_has_muon_bool' = 'Has Muon', 'reco_leading_muon_start_dedx_bool' = 'Start dE/dx', 'reco_flash_score_bool' = 'Flash Score'}
draw_kwargs = {'show_option' = 'differential', 'percentage' = true, 'show_seqeff' = true, 'show_unseqeff' = true}

[[figure]]
name = 'eff_reco_leading_muon_costheta'
type = 'SimpleFigure'
style = 'basic_sbnd'
[[figure.artists]]
type = 'SpineEfficiency'
variable = 'reco_leading_muon_costheta'
groups = ['$\\nu_\\mu$ CC']
cuts = {'reco_valid_flashmatch' = 'Flash Match', 'reco_fiducial_bool' = 'Fiducial', 'reco_has_muon_bool' = 'Has Muon', 'reco_leading_muon_start_dedx_bool' = 'Start dE/dx', 'reco_flash_score_bool' = 'Flash Score'}
draw_kwargs = {'show_option' = 'differential', 'percentage' = true, 'show_seqeff' = true, 'show_unseqeff' = true}

[[figure]]
name = 'eff_table'
type = 'SimpleFigure'
style = 'basic_sbnd'
figsize = [6.0,3.0]
[[figure.artists]]
type = 'SpineEfficiency'
variable = 'reco_leading_muon_momentum_gev'
groups = ['$\\nu_\\mu$ CC']
cuts = {'reco_valid_flashmatch' = 'Flash Match', 'reco_fiducial_bool' = 'Fiducial', 'reco_has_muon_bool' = 'Has Muon', 'reco_leading_muon_start_dedx_bool' = 'Start dE/dx', 'reco_flash_score_bool' = 'Flash Score'}
draw_kwargs = {'show_option' = 'table', 'percentage' = true, 'show_seqeff' = true, 'show_unseqeff' = true}
"""

# %%
nn_score_plots_old = """
[[figure]]
name = 'reco_leading_muon_muon_softmax'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_leading_muon_muon_softmax'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}

[[figure]]
name = 'reco_leading_muon_pion_softmax'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_leading_muon_pion_softmax'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}

[[figure]]
name = 'reco_leading_muon_proton_softmax'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_leading_muon_proton_softmax'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}

[[figure]]
name = 'reco_leading_muon_primary_softmax'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_leading_muon_primary_softmax'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}

"""

# %%
samples_data = """
[samples.data]
key = 'data'
exposure_type = 'pot'
override_category = -1
trees = ['selected1muXNu']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}

[samples.data_offbeam]
key = 'data_offbeam'
exposure_type = 'livetime'
override_category = 7
trees = ['selected1muXNu']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
"""

samples_data_nocut = """
[samples.data]
key = 'data'
exposure_type = 'pot'
override_category = -1
trees = ['selected1muXNu_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}

[samples.data_offbeam]
key = 'data_offbeam'
exposure_type = 'livetime'
override_category = 7
trees = ['selected1muXNu_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
"""

samples_data_1cut = """
[samples.data]
key = 'data'
exposure_type = 'pot'
override_category = -1
trees = ['selected1muXNu_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "reco_valid_flashmatch == 1"

[samples.data_offbeam]
key = 'data_offbeam'
exposure_type = 'livetime'
override_category = 7
trees = ['selected1muXNu_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "reco_valid_flashmatch == 1"
"""

samples_data_cont_1cut = """
[samples.data]
key = 'data'
exposure_type = 'pot'
override_category = -1
trees = ['selected1muXNu']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "reco_valid_flashmatch == 1"

[samples.data_offbeam]
key = 'data_offbeam'
exposure_type = 'livetime'
override_category = 7
trees = ['selected1muXNu']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "reco_valid_flashmatch == 1"
"""

samples_data_2cut = """
[samples.data]
key = 'data'
exposure_type = 'pot'
override_category = -1
trees = ['selected1muXNu_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "(reco_valid_flashmatch == 1) & (reco_fiducial_bool == 1)"

[samples.data_offbeam]
key = 'data_offbeam'
exposure_type = 'livetime'
override_category = 7
trees = ['selected1muXNu_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "(reco_valid_flashmatch == 1) & (reco_fiducial_bool == 1)"
"""

samples_data_3cut = """
[samples.data]
key = 'data'
exposure_type = 'pot'
override_category = -1
trees = ['selected1muXNu_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "(reco_valid_flashmatch == 1) & (reco_fiducial_bool == 1) & (reco_has_muon_bool == 1)"

[samples.data_offbeam]
key = 'data_offbeam'
exposure_type = 'livetime'
override_category = 7
trees = ['selected1muXNu_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "(reco_valid_flashmatch == 1) & (reco_fiducial_bool == 1) & (reco_has_muon_bool == 1)"
"""

samples_data_4cut = """
[samples.data]
key = 'data'
exposure_type = 'pot'
override_category = -1
trees = ['selected1muXNu_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "(reco_valid_flashmatch == 1) & (reco_fiducial_bool == 1) & (reco_has_muon_bool == 1) & (reco_leading_muon_start_dedx_bool == 1)"

[samples.data_offbeam]
key = 'data_offbeam'
exposure_type = 'livetime'
override_category = 7
trees = ['selected1muXNu_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "(reco_valid_flashmatch == 1) & (reco_fiducial_bool == 1) & (reco_has_muon_bool == 1) & (reco_leading_muon_start_dedx_bool == 1)"
"""

samples_data_5cut = """
[samples.data]
key = 'data'
exposure_type = 'pot'
override_category = -1
trees = ['selected1muXNu_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "(reco_valid_flashmatch == 1) & (reco_fiducial_bool == 1) & (reco_has_muon_bool == 1) & (reco_leading_muon_start_dedx_bool == 1) & (reco_flash_score_bool == 1)"

[samples.data_offbeam]
key = 'data_offbeam'
exposure_type = 'livetime'
override_category = 7
trees = ['selected1muXNu_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "(reco_valid_flashmatch == 1) & (reco_fiducial_bool == 1) & (reco_has_muon_bool == 1) & (reco_leading_muon_start_dedx_bool == 1) & (reco_flash_score_bool == 1)"
"""

# %%
covariance_plots = """
[[systematic_recipe]]
name = 'flux'
label = 'Flux Systematics'
pattern = 'Flux'

[[systematic_recipe]]
name = 'multisim_interaction'
label = 'Cross Section Systematics: Multisim'
pattern = 'GENIEReWeight_SBN_v1_multisim_(ZExpAVariation|CCRES|NCRES|NCELVariation|DISBY|FSI)+'

[[systematic_recipe]]
name = 'multisigma_interaction'
label = 'Cross Section Systematics: Multisigma'
pattern = 'GENIEReWeight_SBN_v1_multisigma_(VecFFCCQEshape|RPA_CCQE|CoulombCCQE|NormCCMEC|NormNCMEC|RDec|Theta|NormCCCOH|NormNCCOH|NonRES)+'

[[systematic_recipe]]
name = 'total_xsec'
label = 'Cross Section Systematics'
pattern = '(multisim|multisigma)_interaction'

[[systematic_recipe]]
name = 'stats'
label = 'Statistical Uncertainty'
pattern = '(mc_nu|mc_cos|offbeam)_statistical'

[[systematic_recipe]]
name = 'all'
label = 'Total MC Uncertainty'
pattern = '(flux|total_xsec|stats)'

[[figure]]
name = 'reco_leading_muon_costheta_syst'
type = 'SimpleFigure'
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_leading_muon_costheta'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false, 'draw_error' = 'all'}

"""
# [[figure]]
# name = 'reco_leading_muon_momentum_gev_syst'
# type = 'SimpleFigure'
# style = 'selected_sbnd'
# [[figure.artists]]
# type = 'SpineSpectra1D'
# variable = 'reco_leading_muon_momentum_gev'
# draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false, 'draw_error' = 'all'}

# %%
spectra2d_plots = """
[[figure]]
name = "leading_muon_momentum_smearing"
type = "SimpleFigure"
style = "basic_sbnd"
figsize = [8.0,8.0]
[[figure.artists]]
type = "SpineSpectra2D"
xvariable = "true_leading_muon_momentum_gev"
yvariable = "reco_leading_muon_momentum_gev"
category_types = {"true_leading_muon_momentum_gev" = "histogram", "reco_leading_muon_momentum_gev" = "histogram"}
draw_kwargs = {"logz" = true, "show_option" = "2d", "save_csv_name" = "/exp/sbnd/data/users/brindenc/medulla/test/tmp/leading_muon_momentum_smearing.csv"}

[[figure]]
name = "leading_muon_costheta_smearing"
type = "SimpleFigure"
style = "basic_sbnd"
figsize = [8.0,8.0]
[[figure.artists]]
type = "SpineSpectra2D"
xvariable = "true_leading_muon_costheta"
yvariable = "reco_leading_muon_costheta"
draw_kwargs = {"logz" = true, "show_option" = "2d", "save_csv_name" = "/exp/sbnd/data/users/brindenc/medulla/test/tmp/leading_muon_costheta_smearing.csv"}
"""

# %%
mc_sample = """
[samples]
[samples.mc_nu]
key = 'simulation'
exposure_type = 'pot'
trees = ['selected1muXNu']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}

[samples.mc_cos]
key = 'simulation'
exposure_type = 'pot'
trees = ['selected1muXCos']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0", true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
"""

mc_syst_sample = """
[samples]
[samples.mc_nu]
key = 'simulation'
exposure_type = 'pot'
trees = ['selected1muXNu']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
systematics = ['multisimTree','multisigmaTree']
print_sys = true
save_dir = SAVE_DIR

[samples.mc_cos]
key = 'simulation'
exposure_type = 'pot'
trees = ['selected1muXCos']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0", true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
"""

mc_sample_nocut = """
[samples]
[samples.mc_nu]
key = 'simulation'
exposure_type = 'pot'
trees = ['selected1muXNu_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
print_sys = true

[samples.mc_cos]
key = 'simulation'
exposure_type = 'pot'
trees = ['selected1muXCos_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0", true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
"""

mc_sample_1cut = """
[samples]
[samples.mc_nu]
key = 'simulation'
exposure_type = 'pot'
trees = ['selected1muXNu_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "reco_valid_flashmatch == 1"
print_sys = true

[samples.mc_cos]
key = 'simulation'
exposure_type = 'pot'
trees = ['selected1muXCos_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0", true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "reco_valid_flashmatch == 1"
"""

mc_sample_cont_1cut = """
[samples]
[samples.mc_nu]
key = 'simulation'
exposure_type = 'pot'
trees = ['selected1muXNu']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "reco_valid_flashmatch == 1"
print_sys = true

[samples.mc_cos]
key = 'simulation'
exposure_type = 'pot'
trees = ['selected1muXCos']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0", true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "reco_valid_flashmatch == 1"
"""

mc_sample_2cut = """
[samples]
[samples.mc_nu]
key = 'simulation'
exposure_type = 'pot'
trees = ['selected1muXNu_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "(reco_valid_flashmatch == 1) & (reco_fiducial_bool == 1)"
print_sys = true

[samples.mc_cos]
key = 'simulation'
exposure_type = 'pot'
trees = ['selected1muXCos_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0", true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "(reco_valid_flashmatch == 1) & (reco_fiducial_bool == 1)"
"""

mc_sample_3cut = """
[samples]
[samples.mc_nu]
key = 'simulation'
exposure_type = 'pot'
trees = ['selected1muXNu_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "(reco_valid_flashmatch == 1) & (reco_fiducial_bool == 1) & (reco_has_muon_bool == 1)"
print_sys = true

[samples.mc_cos]
key = 'simulation'
exposure_type = 'pot'
trees = ['selected1muXCos_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0", true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "(reco_valid_flashmatch == 1) & (reco_fiducial_bool == 1) & (reco_has_muon_bool == 1)"
"""

mc_sample_4cut = """
[samples]
[samples.mc_nu]
key = 'simulation'
exposure_type = 'pot'
trees = ['selected1muXNu_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "(reco_valid_flashmatch == 1) & (reco_fiducial_bool == 1) & (reco_has_muon_bool == 1) & (reco_leading_muon_start_dedx_bool == 1)"
print_sys = true

[samples.mc_cos]
key = 'simulation'
exposure_type = 'pot'
trees = ['selected1muXCos_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0", true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "(reco_valid_flashmatch == 1) & (reco_fiducial_bool == 1) & (reco_has_muon_bool == 1) & (reco_leading_muon_start_dedx_bool == 1)"
"""

mc_sample_5cut = """
[samples]
[samples.mc_nu]
key = 'simulation'
exposure_type = 'pot'
trees = ['selected1muXNu_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "(reco_valid_flashmatch == 1) & (reco_fiducial_bool == 1) & (reco_has_muon_bool == 1) & (reco_leading_muon_start_dedx_bool == 1) & (reco_flash_score_bool == 1)"
print_sys = true

[samples.mc_cos]
key = 'simulation'
exposure_type = 'pot'
trees = ['selected1muXCos_none']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0", true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
presel = "(reco_valid_flashmatch == 1) & (reco_fiducial_bool == 1) & (reco_has_muon_bool == 1) & (reco_leading_muon_start_dedx_bool == 1) & (reco_flash_score_bool == 1)"
"""

mc_signal_sample = """
[samples]
[samples.mc_nu]
key = 'simulation'
exposure_type = 'pot'
trees = ['signal1muX']
precompute = { reco_leading_muon_momentum_gev = "reco_leading_muon_momentum / 1000.0",true_leading_muon_momentum_gev = "true_leading_muon_momentum / 1000.0"}
print_sys = true
save_dir = SAVE_DIR
"""

# %%
SAVE_DIR = '/exp/sbnd/data/users/brindenc/medulla/test/tmp_syst/eff'
os.makedirs(SAVE_DIR, exist_ok=True)
cfg = """
[output]
path = SAVE_DIR

[[this_includes]]
file = 'MEDULLA_PATH/spineplot/configurations/analyses/sbnd/numu_incl2025_sbnd_variables_syst.toml'

[[this_includes]]
file = 'MEDULLA_PATH/spineplot/configurations/common/styles.toml'
"""+ mc_signal_sample + analysis_eff_cfg + eff_plots # 
#+ mc_signal_sample + analysis_mc_cfg + spectra2d_plots # Smearing matrices (signal)
#+ mc_sample + analysis_mc_cfg + spectra2d_plots # Smearing matrices (selected)
#+ mc_sample + analysis_eff_cfg + eff_plots # eff plots
#+ mc_sample + analysis_data_cfg + samples_data + spectra_plots + flash_plots + endpoint_plots + nn_score_plots # Data / MC
#+ mc_sample + analysis_data_cfg + samples_data + covariance_plots # Systematics
#systematics = ['multisimTree']

cfg = cfg.replace('MEDULLA_PATH',MEDULLA_PATH).replace('SAVE_DIR',f"'{SAVE_DIR}'")
# Write the string to a file
with open('cfg.toml', 'w') as f:
    f.write(cfg)

#file = '/exp/sbnd/data/users/brindenc/medulla/test/output2.root' #systematics
file = '/exp/sbnd/data/users/brindenc/medulla/test/numucc_incl_sys2.root' #data / MC (small)
#file = '/exp/sbnd/data/users/brindenc/medulla/test/numucc_incl_sys_full.root' #data / MC (full)
#file = '/exp/sbnd/data/users/brindenc/medulla/test/numucc_incl_sys_cont.root' #data / MC (cont small)

analysis = Analysis('cfg.toml', file)
analysis.run(close_figs=False)
# Out:
# --Systematic(statistical, None)--
# 	Fractional uncertainty: 1.74%
# $\nu_\mu$ CC
# $\nu_\mu$ CC
# $\nu_\mu$ CC
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[139], line 31
#      27 #file = '/exp/sbnd/data/users/brindenc/medulla/test/numucc_incl_sys_full.root' #data / MC (full)
#      28 #file = '/exp/sbnd/data/users/brindenc/medulla/test/numucc_incl_sys_cont.root' #data / MC (cont small)
#      30 analysis = Analysis('cfg.toml', file)
# ---> 31 analysis.run(close_figs=False)
#
# File /exp/sbnd/app/users/brindenc/develop/medulla_area/medulla/spineplot/analysis.py:254, in Analysis.run(self, close_figs)
#     252 for artist in self._artists:
#     253     for sample in self._samples.values():
# --> 254         artist.add_sample(sample, sample==ordinate)
#     256 # Check if the output path exists. If not, create it.
#     257 if not os.path.exists(self._output_path):
# ...

# %% [markdown]
# ## Dumby area (for me)

# %%
dt_max = 2/1.6 # ms
dt_window = 1.72 # ms
v = 1.563 # m / ms
dx_window = (dt_window - dt_max) * v # m
dx_window/2
# Out:
# 0.367305

# %%
import pandas as pd
smear = pd.read_csv('/exp/sbnd/data/users/brindenc/medulla/test/tmp/leading_muon_momentum_smearing.csv', index_col=0, header=0)
# Out:
# (25, 25)

# %%
import uproot
tree = uproot.open('/exp/sbnd/data/users/brindenc/medulla/test/numucc_incl2.root')['events']['data']['selected1muX_none']
df = tree.arrays(library='pd')
len(df)
#100k (10k) data (MC) events before selection
# Out:
# 994622

# %%
import uproot
tree = uproot.open('/pnfs/sbnd/scratch/users/mueller/mc5e18/input000.flat.root')
[k for k in tree['recTree;129'].keys() if 'wgt' in k]
# Out:
# ['rec.fake_reco.wgt',
#  'rec.mc.nu.wgt..length',
#  'rec.mc.nu.wgt..totarraysize',
#  'rec.mc.nu.wgt.univ..length',
#  'rec.mc.nu.wgt.univ..totarraysize',
#  'rec.mc.nu.wgt.univ',
#  'rec.mc.nu.wgt.univ..idx',
#  'rec.mc.nu.wgt..idx',
#  'rec.slc.crumbs_result.tpc.nuwgtdirz',
#  'rec.slc.fake_reco.wgt',
#  'rec.slc.nuid.nuwgtdirz',
#  'rec.slc.truth.wgt..length',
#  'rec.slc.truth.wgt..totarraysize',
#  'rec.slc.truth.wgt.univ..length',
#  'rec.slc.truth.wgt.univ..totarraysize',
#  'rec.slc.truth.wgt.univ',
#  'rec.slc.truth.wgt.univ..idx',
#  'rec.slc.truth.wgt..idx']

# %%
import uproot
import numpy as np
tree = uproot.open('/exp/sbnd/data/users/brindenc/medulla/test/output.root')['events']['simulation']['multisimTree;3']
with open('/exp/sbnd/data/users/brindenc/medulla/test/systs_multisim.txt', 'w') as f:
    for key in tree.keys():
        f.write(key + '\n')
